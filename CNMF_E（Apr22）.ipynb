# %%
#外部ライブラリ
import numpy as np
import h5py
import scipy  
import matplotlib.pyplot as plt

# %%
#ガウシアンカーネル
gausian_mask = np.array([
    [1/16,1/8,1/16],
    [1/8,1/4,1/8],
    [1/8,1/4,1/16]
    ])
#畳み込み
def Zet(t):
    return signal.correlate2d(data[t], gausian_mask, mode="same", boundary="wrap") 


#==========================================================================


#時間を固定し場所基準で強い光を取り出す
# Peak to Noise Ratio

def P(t,index):
    P_Nai = Zet(t)/np.std(data[t])
    if index == i:
        return p_Nai[np.unravel_index(np.argmax(P_Nai), P_Nai.shape)]
    else:
        return np.unravel_index(np.argmax(P_Nai), P_Nai.shape)

#==========================================================================

#場所を固定し時間基準で強い相関を取り出す

def L(x,y):
    #x,y
    L=20
    cols = 0
    ones = 0
    box = data[:,x-L:x+L+1,y-L:y+L+1]
    for i in range(-L,L):
        for j in range(-L,L):
            col=np.corrcoef(data[:,x,y],box[:,i,j])
            cols += col[0][1]
            ones += 1
    return cols/ones

#==========================================================================

# %%
#データ読み込み
hdfpath = 
with h5py.File(hdfpath,'r') as f:
    # ファイルオブジェクトをイテレートするとファイル直下のオブジェクト名を返す
    data=f['/Object'][0]

# %%
#内包表記
# http://aifan.jp/リスト内包表記の中で，例外を処理する/


def L_new(x,y):
    L=20
    cols = 0
    ones = 0
    try:
        box = data[:,x-L:x+L+1,y-L:y+L+1]
        for i in range(-L,L):
            for j in range(-L,L):
                col=np.corrcoef(data[:,x,y],box[:,i,j])
                cols += col[0][1]
                ones += 1
        return cols/ones
    except:
        return None
    
    
num = 0
try:
    naiho = [L_new(i,j) for i in range(50) for j in range(50)]
except:
    pass
    
#print(naiho)            
print("fin")
# Out:
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, N
# ...

# %%
print(len(naiho))
# Out:
# 2500

# %%
#for-for
num = 0
for i in range(50):
    for j in range(50):
        try:
            num=[n for n in data if L(i,j) > 0.8]
        except IndexError:
            pass
            #print("IndexError")
print(num.shape)            
print("fin")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-126-cd2c514e40d9> in <module>()
#       3     for j in range(50):
#       4         try:
# ----> 5             num=[n for n in data if L(i,j) > 0.8]
#       6         except IndexError:
#       7             pass
#
# <ipython-input-126-cd2c514e40d9> in <listcomp>(.0)
#       3     for j in range(50):
#       4         try:
# ----> 5             num=[n for n in data if L(i,j) > 0.8]
#       6         except IndexError:
#       7             pass
#
# <ipython-input-114-0056632a5201> in L(x, y)
#      35     for i in range(-L,L):
#      36         for j in range(-L,L):
# ---> 37             col=np.corrcoef(data[:,x,y],box[:,i,j])
#      38             cols += col[0][1]
#      39             ones += 1
#
# ...

# %%
#本体
#forは後から書き直す
el=20

for i in range(355):
        for j in range(266):
            if (L(i,j,o) > 0.8) and (P(k,o) > 8):
                duble = data[:,i-el:i+el+1,j-el:j+el+1]
                #-------------------------------
                Y_BG = [(duble[i][j] < 0.3)/1]
                #-------------------------------
                C_K  = [(duble[i][j] > 0.7)/1]
                #-------------------------------
                #arg_min

# %%
k=0
#x,yはグローバルに場所を指定する
x=0
y=0

while True:
    if (L(x,y,o) < 0.8) or (P(t,o) < 8):
        break
    else:
    duble = M[i-20:i+l+20,j-20:j+20+1]
        x_star = argmax(L*R) <-書き込む　戻り値はx,y
    for i in     
    N_I = duble[i-20:i+l+20,j-20:j+20+1]
    print(N_I)
